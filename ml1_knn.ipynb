# %%
# data preprocessing
import pandas as pd
import csv
from sklearn.utils import shuffle

# check if there is any duplicates

df = pd.read_csv('data 2.csv')
duplicates = df[df.duplicated(keep= False)]

if not duplicates.empty:
    print("Duplicated rows found:")
    print(duplicates)

df_cleaned = df.drop_duplicates()
print(f"Number of rows after removing duplicates: {len(df_cleaned)}")

# relabel the dataset 
df_cleaned['popularity'] = pd.qcut(df_cleaned['popularity'], q=4, labels=[0, 1, 2, 3])

# shuffle
# frac=1: select randomly all rows- 100%
df_shuffled = df_cleaned.sample(frac=1).reset_index(drop=True)

# export dataset into a new csv file
df_shuffled.to_csv("shuffled_dataset.csv", index=False)
# Out:
# Number of rows after removing duplicates: 170653

# %%
import pandas as pd
import csv
from sklearn.model_selection import train_test_split


data= pd.read_csv('shuffled_dataset.csv')
#train= train2+ val
#20% for test set
train, test= train_test_split(data, test_size= 0.2)
#use .head() to visualize in a table + an int as parameter

#train2 is the real training dataset that we use
#val is for validation
#10% for validation set
train2, val= train_test_split(train, test_size= 0.1)

#convert to file csv 
train2.to_csv("FinalTrain_set.csv")
val.to_csv("FinalVal_set.csv")
test.to_csv("FinalTest_set.csv")

# %%
# picks top k features based on a scoring function
from sklearn.feature_selection import SelectKBest
# scoring function = ANOVA F-test to find the features most related to the target variable
from sklearn.feature_selection import f_classif
import pandas as pd

# Load data
data = pd.read_csv('shuffled_dataset.csv')

# Only choose numeric columns (not categorical)
X = data[['valence', 'year', 'acousticness', 'danceability', 'duration_ms', 'energy', 'instrumentalness',
          'liveness', 'loudness', 'speechiness', 'tempo', 'explicit','key','mode']]
y = data['popularity']

# Apply SelectKBest
# create SelectKBest using f_classif 
# k: top k features most related to y
fvalue_Best = SelectKBest(f_classif, k= 5)
# fit: computes F score between each feature in X & target y
# transform: keep only top 3 scoring features 
X_kbest = fvalue_Best.fit_transform(X, y)

f_scores= fvalue_Best.scores_
# Get selected feature names by applying X.columns
# fvalue_Best.get_support(): return boolean mask indicating which features were selected by SelectKBest
feature_scores = list(zip(X.columns, f_scores))
sorted_features = sorted(feature_scores, key=lambda x: x[1], reverse=True)

# Print sorted F-scores
print("All features sorted by F-score:")
for feature, score in sorted_features:
    print(f"{feature}: {score:.4f}")
# Out:
# All features sorted by F-score:
# year: 140889.9554
# acousticness: 28613.2461
# energy: 17824.7398
# loudness: 14074.4366
# instrumentalness: 5782.9568
# speechiness: 3434.6854
# explicit: 3295.0445
# danceability: 2258.6676
# tempo: 1103.8337
# duration_ms: 432.6971
# liveness: 355.4197
# valence: 311.8713
# mode: 142.4507
# key: 10.8784

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler


data = pd.read_csv('shuffled_dataset.csv')
X = data[['valence', 'year', 'acousticness', 'danceability', 'duration_ms', 'energy', 'instrumentalness',
          'liveness', 'loudness', 'speechiness', 'tempo', 'explicit', 'key', 'mode']]

# shapet pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler


data = pd.read_csv('shuffled_dataset.csv')
X = data[['year', 'acousticness', 'energy', 'instrumentalness', 'loudness', 'speechiness', 'explicit',
          'danceability', 'tempo', 'duration_ms', 'liveness', 'valence', 'mode', 'key']]

# shape= number of elements in each dimension
n_samples, n_features = X.shape
y = data['popularity']

scaler = StandardScaler()
# scale for better performance (standardization)
X_scaled = scaler.fit_transform(X)


pca = PCA()
pca.fit(X_scaled)
# get eigenvalues of principal components (larger eigenvalues -> component captures more of the dataset’s variability)
real_eigenvalues = pca.explained_variance_


# Plotting
plt.figure(figsize=(10, 6))
plt.plot(range(1, n_features+1), real_eigenvalues, marker='o')
plt.title('Scree Plot with Parallel Analysis (Manual)')
plt.xlabel('Component Number')
plt.ylabel('Eigenvalue')
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

data= pd.read_csv('shuffled_dataset.csv')
#only choose numeric columns (not categorial)
numeric_cols= data.select_dtypes(include=['number'])

correlation= numeric_cols.corr().round(2)
sns.heatmap(correlation, annot = True)
plt.figure(figsize=(100,100))  # Phóng to kích thước hình ảnh 
plt.show()

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler


# Load training data
training = pd.read_csv("FinalTrain_set.csv", usecols=['name', 'popularity', 'energy', 'loudness', 'year','acousticness','instrumentalness'])
training_array = training[['energy', 'loudness', 'year','acousticness','instrumentalness']].to_numpy()
category_array = training['popularity'].to_numpy()


#Load validating data
validating= pd.read_csv("FinalVal_set.csv", usecols= ['name', 'popularity', 'energy', 'loudness', 'year','acousticness','instrumentalness'])
validating_array= validating[['energy', 'loudness', 'year','acousticness','instrumentalness']].to_numpy()


def minkowski_distance(x, y, p= 5):
    sum=0
    for i in range(len(x)):
        sum += abs(x[i] - y[i])**p
    return sum ** (1 / p)

# K-Nearest Neighbors (KNN) function
# point: STT của observation trong validateSet
# k: k nearest neighbors

def KNN_recommend (trainSet, trainLabels, validateSet, point, k):
    distances = []

    # Calculate distances between the point and all training data
    for i in range(len(trainSet)):
        dist = minkowski_distance(trainSet[i], validateSet[point])
        #add distances to the list
        distances.append((dist, i, trainLabels[i]))

    # Sort distances in descending order and select top k
    distances.sort()
    top_k_distances = distances[:k] 


    # Display the song details 
    val_row= validating.iloc[point]
    print(f"The selected song: {val_row['name']}- Year: {val_row['year']}, Energy: {val_row['energy']}, "
    f"Loudness: {val_row['loudness']}, Acousticness: {val_row['acousticness']}, Instrumentalness: {val_row['instrumentalness']}, Popularity score: {val_row['popularity']}")
    
    print(f"First {k} neighbors: ")
    for i, (dist, idx, _) in enumerate(top_k_distances):
        row = training.iloc[idx]  # Get song details from DataFrame
        print(f"{i}. {row['name']}- Year: {row['year']}, Energy: {row['energy']}, "
        f"Loudness: {row['loudness']}, Acousticness: {row['acousticness']}, Instrumentalness: {row['instrumentalness']}, Popularity score: {row['popularity']}, Distance: {dist}")

    counts = {0: 0, 1: 0, 2: 0, 3: 0}
    for _, _,  category in top_k_distances:
        counts[category] += 1
    print(f"Predicted popularity: {max (counts, key= counts.get)}")


#Scale the features for better performance
scaler= StandardScaler()
training_array_scaled= scaler.fit_transform(training_array)
validating_array_scaled= scaler.transform(validating_array)

KNN_recommend(training_array_scaled, category_array, validating_array_scaled, 200, 75)
# Out:
# The selected song: Mi Gente- Year: 1975, Energy: 0.8740000000000001, Loudness: -3.4130000000000003, Acousticness: 0.368, Instrumentalness: 1.66e-05, Popularity score: 3
# First 75 neighbors:
# 0. Cantemos- Year: 1973, Energy: 0.856, Loudness: -3.711, Acousticness: 0.361, Instrumentalness: 7.31e-05, Popularity score: 1, Distance: 0.08525964335867313
# 1. Cantemos- Year: 1973, Energy: 0.8540000000000001, Loudness: -3.729, Acousticness: 0.369, Instrumentalness: 4.64e-05, Popularity score: 2, Distance: 0.08903087438258121
# 2. Arbolito- Year: 1973, Energy: 0.8590000000000001, Loudness: -3.765, Acousticness: 0.332, Instrumentalness: 0.0, Popularity score: 1, Distance: 0.10412509826924754
# 3. Beast Of Burden - Remastered- Year: 1978, Energy: 0.878, Loudness: -3.864, Acousticness: 0.39, Instrumentalness: 0.000778, Popularity score: 2, Distance: 0.11966867608579886
# 4. The Fire Down Below- Year: 1976, Energy: 0.843, Loudness: -2.83, Acousticness: 0.391, Instrumentalness: 0.0, Popularity score: 3, Distance: 0.12705891595875385
# 5. It Takes Time- Year: 1975, Energy: 0.893, Loudness: -4.383, Acousticness: 0.429, Instrumentalness: 7.62e-06, Popularity score: 1, Distance: 0.19156383452435827
# 6. Need Your Loving Tonight - Remastered 2011- Year: 1980, Energy: 0.8759999999999999, Loudness: -3.881, Acousticness: 0.329, Instrumentalness: 0.0, Popularity score: 1, Distance: 0.19506043761563385
# 7. El Todopoderoso- Year: 1975, Energy: 0.863, Loudness: -3.571, Acousticness: 0.448, Instrumentalness: 0.000192, Popularity score: 3, Distance: 0.2128059878477804
# 8. Dead Flowers - 2009 Mix- Year: 1971, Energy: 0.862, Loudness: -4.599, Acousticness: 0.33, Instrumentalness: 1.7e-05, Popularity score: 1, Distance: 0.2178594088167656
# 9. Dead Flowers - 2009 Mix- Year: 1971, Energy: 0.862, Loudness: -4.599, Acousticness: 0.33, Instrumentalness: 1.7e-05, Popularity score: 1, Distance: 0.2178594088167656
# 10. Dead Flowers - 2009 Mix- Year: 1971, Energy: 0.862, Loudness: -4.599, Acousticness: 0.33, Instrumentalness: 1.7e-05, Popularity score: 3, Distance: 0.2178594088167656
# 11. Accidents Never Happen- Year: 1979, Energy: 0.914, Loudness: -4.546, Acousticness: 0.324, Instrumentalness: 2.6e-05, Popularity score: 1, Distance: 0.21836731443015303
# 12. Hot Sand- Year: 1969, Energy: 0.888, Loudness: -4.135, Acousticness: 0.35, Instrumentalness: 0.0, Popularity score: 1, Distance: 0.23368716885794238
# 13. Nutbush City Limits- Year: 1975, Energy: 0.847, Loudness: -4.74, Acousticness: 0.326, Instrumentalness: 0.0083299999999999, Popularity score: 2, Distance: 0.23498602772192553
# 14. If It Wasn't For The Nights- Year: 1979, Energy: 0.879, Loudness: -4.68, Acousticness: 0.301, Instrumentalness: 0.000914, Popularity score: 3, Distance: 0.24103111802889135
# 15. Hard Times- Year: 1979, Energy: 0.937, Loudness: -3.703, Acousticness: 0.332, Instrumentalness: 1.59e-05, Popularity score: 2, Distance: 0.24143367293098844
# 16. The Boogie Man- Year: 1973, Energy: 0.8859999999999999, Loudness: -3.261, Acousticness: 0.277, Instrumentalness: 0.00035, Popularity score: 2, Distance: 0.24222214308851195
# 17. What Are You Doin' In My Life?- Year: 1979, Energy: 0.938, Loudness: -4.023, Acousticness: 0.362, Instrumentalness: 0.00937, Popularity score: 1, Distance: 0.2451508494555401
# 18. What Are You Doin' In My Life?- Year: 1979, Energy: 0.938, Loudness: -4.023, Acousticness: 0.362, Instrumentalness: 0.00937, Popularity score: 1, Distance: 0.2451508494555401
# 19. What Are You Doin' In My Life?- Year: 1979, Energy: 0.938, Loudness: -4.023, Acousticness: 0.362, Instrumentalness: 0.00937, Popularity score: 1, Distance: 0.2451508494555401
# 20. Love Grows (Where My Rosemary Goes)- Year: 1970, Energy: 0.8240000000000001, Loudness: -4.613, Acousticness: 0.403, Instrumentalness: 0.0, Popularity score: 3, Distance: 0.24693624986531515
# 21. Mexico- Year: 1976, Energy: 0.914, Loudness: -4.8580000000000005, Acousticness: 0.366, Instrumentalness: 8.42e-06, Popularity score: 1, Distance: 0.25736393849990485
# 22. Some More- Year: 1970, Energy: 0.8390000000000001, Loudness: -4.713, Acousticness: 0.295, Instrumentalness: 0.00236, Popularity score: 1, Distance: 0.2606181552075991
# 23. The House That Jack Built- Year: 1969, Energy: 0.892, Loudness: -4.168, Acousticness: 0.281, Instrumentalness: 0.0, Popularity score: 1, Distance: 0.2674930689922296
# 24. Tente Outra Vez- Year: 1975, Energy: 0.8190000000000001, Loudness: -1.995, Acousticness: 0.307, Instrumentalness: 2.18e-06, Popularity score: 1, Distance: 0.27016525319414064
# 25. Bulbs- Year: 1974, Energy: 0.929, Loudness: -4.8660000000000005, Acousticness: 0.394, Instrumentalness: 0.0229, Popularity score: 2, Distance: 0.27075143928764844
# 26. Touch Me- Year: 1969, Energy: 0.903, Loudness: -4.801, Acousticness: 0.405, Instrumentalness: 0.0128, Popularity score: 3, Distance: 0.2741941595554724
# 27. I Wanna Be With You- Year: 1972, Energy: 0.932, Loudness: -3.835, Acousticness: 0.271, Instrumentalness: 0.0, Popularity score: 2, Distance: 0.27749998412377
# 28. EGO TRIP- Year: 1968, Energy: 0.851, Loudness: -3.587, Acousticness: 0.299, Instrumentalness: 5.37e-06, Popularity score: 1, Distance: 0.27754527620155106
# 29. Who's Making Love- Year: 1980, Energy: 0.926, Loudness: -4.521, Acousticness: 0.274, Instrumentalness: 0.000601, Popularity score: 2, Distance: 0.282549745635623
# 30. Live It Up- Year: 1979, Energy: 0.894, Loudness: -4.215, Acousticness: 0.263, Instrumentalness: 0.0, Popularity score: 3, Distance: 0.28390903975024967
# 31. Do It Roger- Year: 1981, Energy: 0.821, Loudness: -3.68, Acousticness: 0.274, Instrumentalness: 0.0008869999999999, Popularity score: 1, Distance: 0.28696948237885733
# 32. Since You Been Gone- Year: 1978, Energy: 0.82, Loudness: -4.9460000000000015, Acousticness: 0.298, Instrumentalness: 0.0, Popularity score: 1, Distance: 0.2884416666390776
# 33. Scenes from an Italian Restaurant- Year: 1977, Energy: 0.931, Loudness: -4.988, Acousticness: 0.407, Instrumentalness: 0.0005009999999999, Popularity score: 3, Distance: 0.29069751510318836
# 34. Shattered - Remastered- Year: 1978, Energy: 0.952, Loudness: -2.752, Acousticness: 0.415, Instrumentalness: 2.2e-05, Popularity score: 1, Distance: 0.29356412801883364
# 35. Tell The Truth- Year: 1970, Energy: 0.888, Loudness: -4.938, Acousticness: 0.446, Instrumentalness: 0.0549, Popularity score: 1, Distance: 0.29400562159515664
# 36. Warm Love - Live- Year: 1974, Energy: 0.8009999999999999, Loudness: -4.73, Acousticness: 0.324, Instrumentalness: 0.000161, Popularity score: 1, Distance: 0.29405605047993455
# 37. Winds of Change- Year: 1982, Energy: 0.8909999999999999, Loudness: -4.093, Acousticness: 0.279, Instrumentalness: 1.14e-05, Popularity score: 1, Distance: 0.2941679676032562
# 38. Ain't Nobody Straight In L.A.- Year: 1975, Energy: 0.897, Loudness: -5.121, Acousticness: 0.393, Instrumentalness: 0.0249, Popularity score: 2, Distance: 0.3002871911066732
# 39. Dancing in the Street - 2015 Remaster- Year: 1982, Energy: 0.941, Loudness: -3.51, Acousticness: 0.414, Instrumentalness: 1.41e-05, Popularity score: 3, Distance: 0.30042045815488205
# 40. Ex Lion Tamer - 2006 Remastered Version- Year: 1977, Energy: 0.856, Loudness: -4.666, Acousticness: 0.259, Instrumentalness: 0.000673, Popularity score: 2, Distance: 0.3033707085436899
# 41. Light Of Love- Year: 1975, Energy: 0.932, Loudness: -5.069, Acousticness: 0.327, Instrumentalness: 2.28e-06, Popularity score: 1, Distance: 0.3035850208535362
# 42. Chrome Sitar- Year: 1976, Energy: 0.945, Loudness: -2.987, Acousticness: 0.467, Instrumentalness: 0.000256, Popularity score: 1, Distance: 0.3037546462562808
# 43. Ponta De Lança Africano- Year: 1976, Energy: 0.91, Loudness: -3.834, Acousticness: 0.253, Instrumentalness: 0.0, Popularity score: 2, Distance: 0.30694350054591324
# 44. Choirgirl - 2011 Remastered- Year: 1980, Energy: 0.7929999999999999, Loudness: -2.781, Acousticness: 0.341, Instrumentalness: 0.0, Popularity score: 3, Distance: 0.30930749984562317
# 45. Before They Make Me Run - Remastered- Year: 1978, Energy: 0.955, Loudness: -2.3040000000000003, Acousticness: 0.384, Instrumentalness: 0.0175, Popularity score: 1, Distance: 0.3096721950891923
# 46. Ave Gengis Khan- Year: 1968, Energy: 0.917, Loudness: -3.026, Acousticness: 0.297, Instrumentalness: 0.0801, Popularity score: 1, Distance: 0.31025374602990485
# 47. I Want to Be Loved #2- Year: 1977, Energy: 0.933, Loudness: -5.118, Acousticness: 0.373, Instrumentalness: 0.00118, Popularity score: 1, Distance: 0.3115646371891028
# 48. Down By The Lazy River- Year: 1971, Energy: 0.909, Loudness: -5.154, Acousticness: 0.433, Instrumentalness: 0.0, Popularity score: 1, Distance: 0.3120100077261466
# 49. Bad Time - Remastered 2002- Year: 1974, Energy: 0.927, Loudness: -3.1630000000000003, Acousticness: 0.253, Instrumentalness: 0.0, Popularity score: 2, Distance: 0.31257185219433764
# 50. Taking Too Long- Year: 1981, Energy: 0.8420000000000001, Loudness: -3.785, Acousticness: 0.256, Instrumentalness: 0.011, Popularity score: 1, Distance: 0.31365472315834986
# 51. Kingdom Hall - Remastered- Year: 1978, Energy: 0.8759999999999999, Loudness: -4.4510000000000005, Acousticness: 0.25, Instrumentalness: 1.4e-05, Popularity score: 1, Distance: 0.31832412785224146
# 52. Juntos- Year: 1978, Energy: 0.953, Loudness: -4.838, Acousticness: 0.324, Instrumentalness: 3.61e-05, Popularity score: 1, Distance: 0.31840270902847095
# 53. Rolling Down a Mountainside- Year: 1975, Energy: 0.8690000000000001, Loudness: -5.092, Acousticness: 0.443, Instrumentalness: 0.0742, Popularity score: 1, Distance: 0.3188088671126343
# 54. Walk On Water- Year: 1977, Energy: 0.931, Loudness: -4.814, Acousticness: 0.26, Instrumentalness: 0.0, Popularity score: 1, Distance: 0.31896728322416207
# 55. ABC- Year: 1971, Energy: 0.8590000000000001, Loudness: -5.17, Acousticness: 0.448, Instrumentalness: 0.000201, Popularity score: 1, Distance: 0.31944101325275365
# 56. Meus Filhos, Meu Tesouro- Year: 1976, Energy: 0.882, Loudness: -5.226, Acousticness: 0.421, Instrumentalness: 0.0, Popularity score: 1, Distance: 0.31958482493277734
# 57. New Moon on Monday- Year: 1983, Energy: 0.87, Loudness: -4.694, Acousticness: 0.369, Instrumentalness: 0.0, Popularity score: 2, Distance: 0.3203328542814419
# 58. Love Her All I Can- Year: 1975, Energy: 0.912, Loudness: -5.235, Acousticness: 0.363, Instrumentalness: 0.012, Popularity score: 1, Distance: 0.3211852283613171
# 59. Dans les yeux d'Emilie- Year: 1978, Energy: 0.915, Loudness: -5.226, Acousticness: 0.319, Instrumentalness: 0.0192, Popularity score: 3, Distance: 0.3212544730197652
# 60. Zombie- Year: 1977, Energy: 0.942, Loudness: -5.115, Acousticness: 0.388, Instrumentalness: 0.0146, Popularity score: 2, Distance: 0.32187579698680485
# 61. Map Ref 41 Degrees N 93 Degrees W - 2006 Remastered Version- Year: 1979, Energy: 0.893, Loudness: -5.22, Acousticness: 0.436, Instrumentalness: 1.4499999999999992e-05, Popularity score: 2, Distance: 0.32283655401719435
# 62. Love Will Keep Us Together- Year: 1975, Energy: 0.7879999999999999, Loudness: -4.3260000000000005, Acousticness: 0.354, Instrumentalness: 0.0, Popularity score: 3, Distance: 0.32345960941256025
# 63. New Moon on Monday - 2010 Remaster- Year: 1983, Energy: 0.8690000000000001, Loudness: -4.56, Acousticness: 0.449, Instrumentalness: 2.16e-06, Popularity score: 2, Distance: 0.3243929760149778
# 64. In Your Letter- Year: 1980, Energy: 0.894, Loudness: -5.1080000000000005, Acousticness: 0.273, Instrumentalness: 0.0, Popularity score: 2, Distance: 0.32526205281966325
# 65. Tremendo Rumbón- Year: 1976, Energy: 0.787, Loudness: -3.854, Acousticness: 0.379, Instrumentalness: 0.0267, Popularity score: 2, Distance: 0.3253651131545199
# 66. I'm Tired of Life- Year: 1981, Energy: 0.954, Loudness: -3.242, Acousticness: 0.28, Instrumentalness: 0.0, Popularity score: 1, Distance: 0.3273427481872297
# 67. Bringing It Back- Year: 1974, Energy: 0.8079999999999999, Loudness: -4.413, Acousticness: 0.479, Instrumentalness: 0.067, Popularity score: 1, Distance: 0.3275828581500497
# 68. The Hell Of It- Year: 1974, Energy: 0.909, Loudness: -5.285, Acousticness: 0.336, Instrumentalness: 0.000698, Popularity score: 2, Distance: 0.32960322744265297
# 69. Juntos- Year: 1981, Energy: 0.953, Loudness: -4.838, Acousticness: 0.324, Instrumentalness: 3.61e-05, Popularity score: 3, Distance: 0.3300284864254163
# 70. Shadows on Your Side - 2010 Remaster- Year: 1983, Energy: 0.943, Loudness: -4.275, Acousticness: 0.399, Instrumentalness: 1.34e-06, Popularity score: 1, Distance: 0.3317932300699009
# 71. Special To Me (Phoenix Audition Song)- Year: 1974, Energy: 0.7979999999999999, Loudness: -4.975, Acousticness: 0.458, Instrumentalness: 6.5e-06, Popularity score: 1, Distance: 0.33459201697530916
# 72. Like Janis- Year: 1970, Energy: 0.813, Loudness: -3.846, Acousticness: 0.488, Instrumentalness: 0.0, Popularity score: 2, Distance: 0.3346788595210657
# 73. A Girl Called Johnny - 2002 Remaster- Year: 1983, Energy: 0.947, Loudness: -3.948, Acousticness: 0.396, Instrumentalness: 0.0, Popularity score: 3, Distance: 0.336568635434345
# 74. Who's Lovin' You- Year: 1971, Energy: 0.7929999999999999, Loudness: -4.395, Acousticness: 0.471, Instrumentalness: 0.000422, Popularity score: 1, Distance: 0.3367331343704942
# Predicted popularity: 1

# %%
import pandas as pd
training = pd.read_csv("FinalTrain_set.csv")
print(training['popularity'].value_counts())
# Out:
# popularity
# 2    31573
# 0    30967
# 1    30579
# 3    29750
# Name: count, dtype: int64

# %%
import numpy as np
import pandas as pd
import math
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

# Load training data
training = pd.read_csv("FinalTrain_set.csv", usecols=['name', 'popularity', 'year', 'energy', 'acousticness', 'instrumentalness', 'loudness'])
training_array = training[['year', 'energy', 'acousticness', 'instrumentalness', 'loudness']].to_numpy()
category_array = training['popularity'].to_numpy()


#Load validating data
validating= pd.read_csv("FinalVal_set.csv", usecols= ['name', 'popularity', 'year', 'energy', 'acousticness','instrumentalness','loudness'])
validating_array= validating[['year', 'energy', 'acousticness', 'instrumentalness', 'loudness']].to_numpy()
valcat_array= validating['popularity'].to_numpy()

#Load testing data
testing= pd.read_csv("FinalTest_set.csv", usecols= ['name', 'popularity', 'year', 'energy', 'acousticness','instrumentalness', 'loudness'])
test_array= testing[['year', 'energy', 'acousticness', 'instrumentalness', 'loudness']].to_numpy()
testcat_array= testing['popularity'].to_numpy()


# Scale the features for better performance
scaler= StandardScaler()
training_array_scaled= scaler.fit_transform(training_array)
validating_array_scaled= scaler.transform(validating_array)
testing_array_scaled= scaler.transform(test_array)

knn= KNeighborsClassifier(n_neighbors= 75)
knn.fit(training_array_scaled, category_array)

val_pred= knn.predict(validating_array_scaled)
test_pred= knn.predict(testing_array_scaled)

    
print("Accuracy score of the validating set: ", accuracy_score(valcat_array, val_pred))
print("Accuracy score of the testing set: ", accuracy_score(testcat_array, test_pred))
# Out:
# Accuracy score of the validating set:  0.6854903684171977
# Accuracy score of the testing set:  0.6885236295449885

# %%
import numpy as np
import pandas as pd
import math
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

# Load training data
training = pd.read_csv("FinalTrain_set.csv", usecols=['name', 'popularity', 'year', 'energy', 'acousticness', 'instrumentalness', 'loudness'])
training_array = training[['year', 'energy', 'acousticness', 'instrumentalness', 'loudness']].to_numpy()
category_array = training['popularity'].to_numpy()


#Load validating data
validating= pd.read_csv("FinalVal_set.csv", usecols= ['name', 'popularity', 'year', 'energy', 'acousticness','instrumentalness','loudness'])
validating_array= validating[['year', 'energy', 'acousticness', 'instrumentalness', 'loudness']].to_numpy()
valcat_array= validating['popularity'].to_numpy()

#Load testing data
testing= pd.read_csv("FinalTest_set.csv", usecols= ['name', 'popularity', 'year', 'energy', 'acousticness','instrumentalness', 'loudness'])
test_array= testing[['year', 'energy', 'acousticness', 'instrumentalness', 'loudness']].to_numpy()
testcat_array= testing['popularity'].to_numpy()


# Scale the features for better performance
scaler= StandardScaler()
training_array_scaled= scaler.fit_transform(training_array)
validating_array_scaled= scaler.transform(validating_array)
testing_array_scaled= scaler.transform(test_array)

knn= KNeighborsClassifier(n_neighbors= 75, metric= 'cityblock')
knn.fit(training_array_scaled, category_array)

val_pred= knn.predict(validating_array_scaled)
test_pred= knn.predict(testing_array_scaled)

    
print("Accuracy score of the validating set: ", accuracy_score(valcat_array, val_pred))
print("Accuracy score of the testing set: ", accuracy_score(testcat_array, test_pred))
# Out:
# Accuracy score of the validating set:  0.6861495641983447
# Accuracy score of the testing set:  0.6888752160792242

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score
from sklearn.neighbors import KNeighborsClassifier
import matplotlib.pyplot as plt


# Load training data
training = pd.read_csv("FinalTrain_set.csv", usecols=['name', 'popularity', 'energy', 'loudness', 'year','acousticness','instrumentalness'])
training_array = training[['energy', 'loudness', 'year','acousticness','instrumentalness']].to_numpy()
category_array = training['popularity'].to_numpy()

#Load validating data
validating= pd.read_csv("FinalVal_set.csv", usecols= ['name', 'popularity', 'energy', 'loudness', 'year','acousticness','instrumentalness'])
validating_array= validating[['energy', 'loudness', 'year','acousticness','instrumentalness']].to_numpy()
valcat_array = validating['popularity'].to_numpy()

#Load testing data
testing= pd.read_csv("FinalTest_set.csv", usecols= ['name', 'popularity', 'energy', 'loudness', 'year','acousticness','instrumentalness'])
test_array= testing[['energy', 'loudness', 'year','acousticness','instrumentalness']].to_numpy()
testcat_array= testing['popularity'].to_numpy()

#Scale the features for better performance
scaler= StandardScaler()
training_array_scaled= scaler.fit_transform(training_array)
validating_array_scaled= scaler.transform(validating_array)
test_array_scaled= scaler.transform(test_array)

val_acc= []
test_acc= []
k = np.arange(1,351,25)

for i in k:
    knn= KNeighborsClassifier(n_neighbors= i)
    knn.fit(training_array_scaled, category_array)
    validate_pred= knn.predict(validating_array_scaled)
    test_pred = knn.predict(test_array_scaled)
    val_acc.append(accuracy_score(valcat_array, validate_pred))
    test_acc.append(accuracy_score(testcat_array, test_pred))

plt.figure(figsize=(8, 6))
plt.plot(k, val_acc, color='purple',label= "Validating accuracy")
plt.plot(k, test_acc, color= 'blue', label= "Testing accuracy")
plt.xlabel('Number of neighbors')
plt.ylabel('Accuracy')
plt.legend()
plt.show()
